# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import folium

# %%
Mahale = gpd.read_file(r"E:\ArcGIS Pro\bin\Python\envs\gisenv\Shp\Mahalat.shp")
Mahale.head()
# Out:
#    OBJECTID_1  OBJECTID  REGION    NAME_MAHAL  CODE OLD_CODE      NAME_REGIO  \
# 0           1         1    13.0        زينبيه  1307  5721280        زينبيه13
# 1           2         2    13.0          شورا  1304  5721274          شورا13
# 2           3         3     8.0     تهرانپارس   807  5720602      تهرانپارس8
# 3           4         4     4.0        جواديه   420  5720770         جواديه4
# 4           5         5    21.0  شهرک استقلال  2118   212120  شهرک استقلال21
#
#                ENAME   ID          AREA  ...           AREA_CATEG FLAG  \
# 0         Zeynabiyeh  159  1.240729e+06  ...  از 100 تا 150 هکتار  0.0
# 1              Shora  136  7.261168e+05  ...   از 50 تا 100 هکتار  0.0
# 2         Tehranpars  138  2.410166e+06  ...  از 200 تا 300 هکتار  0.0
# 3          Javadiyeh  139  1.770828e+06  ...  از 150 تا 200 هکتار  0.0
# 4  shahrak esteghlal  210  1.166023e+07  ...    400 هکتار و بیشتر  0.0
#
#    ID_UNIQUE  NAHIE GEOM_AREA  GEOM_LEN    Shape_Leng    Shape_Le_1  \
# 0      172.0   1304       0.0       0.0   9522.099426   9522.099426
# 1      173.0   1303       0.0       0.0   3926.180725   3926.180725
# 2      174.0   0801       0.0       0.0   8041.317136   8041.317136
# 3      175.0   0406       0.0       0.0   6857.026087   6857.026087
# 4      181.0   2102       0.0       0.0  13893.337579  13893.337579
#
#      Shape_Area                                           geometry
# 0  1.240729e+06  POLYGON ((545290.471 3951036.932, 545314.222 3...
# 1  7.261168e+05  POLYGON ((545408.551 3951622.957, 545408.392 3...
# 2  2.410166e+06  POLYGON ((545426.000 3952806.364, 545425.162 3...
# 3  1.770828e+06  POLYGON ((550285.834 3955333.336, 550345.492 3...
# 4  1.166023e+07  POLYGON ((518282.954 3950218.318, 519312.482 3...
#
# [5 rows x 21 columns]

# %%
Mahale.plot()
# Out:
# <AxesSubplot:>

# %%
Mahale.plot(color='red', edgecolor = 'black')
# Out:
# <AxesSubplot:>

# %%
Mahale.plot('NAME_MAHAL')
# Out:
# <AxesSubplot:>

# %%
Mahale.plot(column = "REGION", legend = True)
# Out:
# <AxesSubplot:>

# %%
Mahale.plot(column = "REGION", cmap = 'hsv', legend = True)
# Out:
# <AxesSubplot:>

# %%
Mahale.plot(column = "REGION", cmap = 'hsv' , legend = True, legend_kwds = {'label':"Region"})
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize = (7,7))
driver = make_axes_locatable(ax)
cax = driver.append_axes('right', size = '7%', pad= 0.1 )
Mahale.plot(column = "REGION", cmap = 'hsv', legend = True, legend_kwds = {'label':"Region"}, ax = ax, cax = cax)
# Out:
# <AxesSubplot:>

# %%
Metro_Line = gpd.read_file(r"E:\ArcGIS Pro\bin\Python\envs\gisenv\Shp\Metro_Line.shp")
Metro_Line
# Out:
#     OBJECTID    ENTITY     LAYER  ELEVATION  THICKNESS  COLOR  \
# 0          1  Polyline  M_ROUTE5        0.0        0.0     53
# 1          2  Polyline  M_ROUTE1        0.0        0.0    230
# 2          3  Polyline  M_ROUTE3        0.0        0.0    183
# 3          4  Polyline  M_ROUTE2        0.0        0.0     32
# 4          5  Polyline  M_ROUTE6        0.0        0.0    124
# 5          6       NaN       NaN        0.0        0.0      0
# 6          7       NaN       NaN        0.0        0.0      0
# 7          8       NaN       NaN        0.0        0.0      0
# 8          9       NaN       NaN        0.0        0.0      0
# 9         10       NaN       NaN        0.0        0.0      0
# 10        11  Polyline  M_ROUTE8        0.0        0.0     96
# 11        12       NaN       NaN        0.0        0.0      0
#
#                                           Name  Line    Shape_Leng  \
# 0              ميدان صادقيه (تهران)-گلشهر-خط 5     5  16377.091186
# 1                           تجريش-کهريزک- خط 1     1  45446.708873
# 2   بزرگراه شهيد آيت الله سعيدي-شهرک قائم-خط 3     3  34225.061933
# 3     ميدان صادقيه(تهران)-فرهنگسراي اشراق-خط 2     2  30099.902652
# 4   شهرک دولت آباد-سولقان (شهرک شرکت نفت-خط 6)     6  38987.964880
# 5                                        خط 11    11  28006.792460
# 6                                        خط 10    10  40776.678908
# 7      شهرک اميرالمومنين -فرودگاه مهرآباد-خط 7     7  29509.030651
# 8                    شهيد کلاهدوز-اکباتان-خط 4     4  26590.803014
# 9                    شهيد کلاهدوز-اکباتان-خط 4     4   7500.878624
# 10                                        خط 8     8  35476.081738
# 11                                        خط 9     9  41383.235250
#
#                                              geometry
# 0   LINESTRING Z (514067.554 3955287.359 0.000, 51...
# 1   MULTILINESTRING Z ((533549.879 3930947.051 0.0...
# 2   LINESTRING Z (547540.669 3962146.722 0.000, 54...
# 3   LINESTRING Z (529865.207 3952595.970 0.000, 53...
# 4   LINESTRING Z (524837.609 3959243.814 0.000, 52...
# 5   LINESTRING Z (522690.320 3952229.936 0.000, 52...
# 6   LINESTRING Z (548116.505 3956632.985 0.000, 54...
# 7   LINESTRING Z (528611.468 3959658.395 0.000, 52...
# 8   LINESTRING Z (548116.505 3956632.985 0.000, 54...
# 9   MULTILINESTRING Z ((527709.722 3952185.565 0.0...
# 10  LINESTRING Z (544861.390 3954698.285 0.000, 54...
# 11  LINESTRING Z (543747.005 3943566.810 0.000, 54...

# %%
Metro_Line.plot('Line', legend = True, cmap = 'Dark2')
# Out:
# <AxesSubplot:>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)
Mahale.plot(ax = ax1)
Metro_Line.plot(ax = ax2)
# Out:
# <AxesSubplot:>

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize = (20, 10))
Mahale.plot(ax = ax1, column = "REGION", cmap = 'hsv')
Metro_Line.plot(ax = ax2, column ='Line', cmap = 'Dark2')
# Out:
# <AxesSubplot:>

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize = (10, 8))
Mahale.plot(ax = ax1, column = "REGION", cmap = 'hsv')
Metro_Line.plot(ax = ax2, column ='Line', cmap = 'Dark2')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize = (10, 8))
Mahale.plot(ax = ax, column = "REGION", cmap = 'hsv')
Metro_Line.plot(ax = ax, column ='Line', cmap = 'Dark2')
# Out:
# <AxesSubplot:>

# %%
Metro_St = gpd.read_file(r"E:\ArcGIS Pro\bin\Python\envs\gisenv\Shp\Metro_Station.shp")

# %%
fig, ax = plt.subplots(figsize = (10, 8))
Mahale.plot(ax = ax, column = "REGION", cmap = 'hsv')
Metro_Line.plot(ax = ax, column ='Line', cmap = 'Dark2')
Metro_St.plot(ax = ax, markersize = 14)
# Out:
# <AxesSubplot:>

# %%
Metro_St.crs
# Out:
# <Projected CRS: EPSG:32639>
# Name: WGS 84 / UTM zone 39N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 48°E and 54°E, northern hemisphere between equator and 84°N, onshore and offshore. Azerbaijan. Bahrain. Islamic Republic of Iran. Iraq. Kazakhstan. Kuwait. Oman. Qatar. Russian Federation. Saudi Arabia. Somalia. Turkmenistan. United Arab Emirates. Yemen.
# - bounds: (48.0, 0.0, 54.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 39N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
